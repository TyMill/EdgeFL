# %% [markdown]
# # EdgeFL Simulation Example
# This notebook runs a basic federated learning simulation using environmental data.

# %%
# Example call (code assumes that EdgeFL is installed and simulation module is available)
from edgefl.simulation.simulation import run_simulation

# Run federated simulation for 5 rounds
run_simulation(rounds=5)

# %% [markdown]
# ### Next Steps:
# - Visualize loss or MSE over rounds
# - Compare with centralized model
# - Explore client-wise performance
